# %%
import sys
import os

# chemin vers la racine du projet (le dossier qui contient esg_lib, external, tests, etc.)
project_root = r"C:/Users/ZEROUAL/Documents/ESILV_A4_cours/Project/esg-quicksight-as-code-main/esg-quicksight-as-code-main"

# on ajoute la racine du projet
sys.path.append(project_root)

# on ajoute aussi directement le dossier tests
tests_path = os.path.join(project_root, "tests")
sys.path.append(tests_path)

print("Racine projet :", project_root)
print("Dossier tests :", tests_path)
# Out:
# Racine projet : C:/Users/ZEROUAL/Documents/ESILV_A4_cours/Project/esg-quicksight-as-code-main/esg-quicksight-as-code-main
# Dossier tests : C:/Users/ZEROUAL/Documents/ESILV_A4_cours/Project/esg-quicksight-as-code-main/esg-quicksight-as-code-main\tests

# %%
import os

print(os.listdir(tests_path))
# Out:
# ['advanced_visuals_output.json', 'README.md', 'test_dataset.py', 'test_parameters.py', 'test_parameters_controls.py', 'test_sheets.py']

# %%
from test_parameters import run_all_tests

print("Import OK !")
run_all_tests()
# Out:
# Import OK !
#
# LANCEMENT DES TESTS PARAMETRES ESG
#
#
# TEST 1 : Paramètre année
# OK - Paramètre année
#
# TEST 2 : Dropdown année
# OK - Dropdown année
#
# TEST 3 : Paramètre secteur
# OK - Paramètre secteur
#
# TEST 4 : Dropdown secteur (choix unique)
# OK - Dropdown secteur
#
# TEST 5 : Liste secteurs (multi-sélection)
# OK - Liste secteurs
#
# TEST 6 : Région / Pays (paramètre + dropdown)
# OK - Région / Pays
#
# TEST 7 : Type d'actif (paramètre + dropdown)
# OK - Type d'actif
#
# TEST 8 : Intensité (paramètre + slider simple)
# OK - Intensité globale
#
# TEST 9 : Intensité min / max + sliders
# OK - Intensité min/max
#
# TEST 10 : Sous-secteurs (liste multi-sélection)
# OK - Sous-secteurs
#
# Tous les tests de parameters_controls.py ont réussi.

# %%
from test_parameters import run_all_tests
run_all_tests()
# Out:
# LANCEMENT DES TESTS PARAMETRES ESG
#
#
# TEST 1 : Paramètre année
# OK - Paramètre année
#
# TEST 2 : Dropdown année
# OK - Dropdown année
#
# TEST 3 : Paramètre secteur
# OK - Paramètre secteur
#
# TEST 4 : Dropdown secteur (choix unique)
# OK - Dropdown secteur
#
# TEST 5 : Liste secteurs (multi-sélection)
# OK - Liste secteurs
#
# TEST 6 : Région / Pays (paramètre + dropdown)
# OK - Région / Pays
#
# TEST 7 : Type d'actif (paramètre + dropdown)
# OK - Type d'actif
#
# TEST 8 : Intensité (paramètre + slider simple)
# OK - Intensité globale
#
# TEST 9 : Intensité min / max + sliders
# OK - Intensité min/max
#
# TEST 10 : Sous-secteurs (liste multi-sélection)
# OK - Sous-secteurs
#
# Tous les tests de parameters_controls.py ont réussi.
