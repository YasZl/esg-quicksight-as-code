# %%
pip install pandas matplotlib seaborn plotly
# Out:
# Requirement already satisfied: pandas in c:\users\zeroual\anaconda\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\zeroual\anaconda\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\zeroual\anaconda\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\zeroual\anaconda\lib\site-packages (6.4.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\zeroual\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zeroual\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zeroual\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zeroual\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zeroual\anaconda\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\zeroual\anaconda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zeroual\anaconda\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\zeroual\anaconda\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\zeroual\anaconda\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\zeroual\anaconda\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\zeroual\anaconda\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\zeroual\anaconda\lib\site-packages (from plotly) (2.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\zeroual\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

file_path = "demo_cross_asset_type_2025-03-31_ORIGINAL.xlsx"

# Lire la feuille Inventory sans header
raw = pd.read_excel(file_path, sheet_name="Inventory", header=None)

# Trouver la ligne d'en-tête exacte
header_row = 3   # On l'a confirmé dans ton screenshot
print("Header row =", header_row)

# Relire proprement avec header
df = pd.read_excel(file_path, sheet_name="Inventory", header=header_row)

df.head()
# Out:
# C:\Users\ZEROUAL\ANACONDA\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
# Header row = 3
# C:\Users\ZEROUAL\ANACONDA\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
#           Portfolio ID *       Portfolio name * Portfolio currency *  \
# 0  demo_cross_asset_type  demo_cross_asset_type                  EUR
# 1  demo_cross_asset_type  demo_cross_asset_type                  EUR
# 2  demo_cross_asset_type  demo_cross_asset_type                  EUR
# 3  demo_cross_asset_type  demo_cross_asset_type                  EUR
# 4  demo_cross_asset_type  demo_cross_asset_type                  EUR
#
#    Portfolio validated nav * Portfolio date * Security ID *  \
# 0                      12429       2025-03-31  DE0005545503
# 1                      12429       2025-03-31  US68245XAT63
# 2                      12429       2025-03-31  US68245XAR08
# 3                      12429       2025-03-31  GB0006640972
# 4                      12429       2025-03-31  US8318652091
#
#          Security name *   Security type  CIC Code  \
# 0                  11 AG          Equity       NaN
# 1         1011778 BC ULC  Corporate bond       NaN
# 2         1011778 BC ULC  Corporate bond       NaN
# 3     4imprint Group plc          Equity       NaN
# 4  A O Smith Corporation          Equity       NaN
#
#   Security quotation currency *  \
# 0                           EUR
# 1                           EUR
# 2                           EUR
# 3                           EUR
# 4                           EUR
#
#    Security market valuation in portfolio currency *  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Security market valuation in quotation currency  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Security clean market valuation in portfolio currency  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Security clean market valuation in quotation currency  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Security market exposure in portfolio currency  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Security market exposure in quotation currency  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Accrued income in portfolio currency  Accrued income in quotation currency
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
